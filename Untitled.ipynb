# %%
#Задание 1

# %%
# %matplotlib inline
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

x = np.linspace(-7*np.pi, 2*np.pi, 250)

k, a, b = np.linspace(10,10, num = 3)
k1, a1, b1 = np.linspace(5, 10, num = 3)
k2, a2, b2 = np.linspace(7, 12, num = 3)

print(f'k={k}, a={a}, b={b}')
print(f'k1={k1}, a1={a1}, b1={b1}')
print(f'k2={k2}, a2={a2}, b2={b2}')

plt.figure(figsize = (20, 10))
plt.plot(x, k * np.cos(x - a) + b, label='k, a, b')
plt.plot(x, k1 * np.cos(x - a1) + b1, color='purple', label='k1, a1, b1')
plt.plot(x, k2 * np.sin(x - a2) + b2, color='green', label='k2, a2, b2')

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend(frameon=False)
plt.show()
# Out:
# k=10.0, a=10.0, b=10.0
# k1=5.0, a1=7.5, b1=10.0
# k2=7.0, a2=9.5, b2=12.0

# %%
#Задание 3.1

# %%
import math

def polar2cart(r,phi):
    x = r*math.cos(phi)
    y = r*math.sin(phi)
    return x,y

polar2cart(2,45)
# Out:
# (1.0506439776354595, 1.7018070490682369)

# %%
#Задание 3.2

# %%
phi = np.arange(0., 2., 1./180.)*np.pi 

plt.polar(phi, [5]*len(phi)) 

plt.show()

# %%
#Задание 3.3

# %%
phi = np.arange(3, 6, 2)
print(phi)
rho = np.arange(3, 6, 2)
print(rho)

plt.polar(phi, rho)         

plt.show()
# Out:
# [3 5]
# [3 5]

# %%
#Задание 4.1

# %%
x = np.linspace(-2, 3, 201)

plt.figure(figsize = (6, 12))
plt.plot(x, (- 1/x)+2)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1,5) 
plt.grid(True)

plt.show()

from scipy.optimize import fsolve

def equations(p):
    x, y = p
    return (x**2 - 1 - y, (- 1/x)+2 - y)

x1, y1 =  fsolve(equations, (2, 4))
x2, y2 =  fsolve(equations, (0.5, 0.5))
x3, y3 =  fsolve(equations, (-1, 1))
              
print (x1, y1)
print (x2, y2)
print (x3, y3)
# Out:
# C:\Temp/ipykernel_10872/2493149672.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x, (- 1/x)+2)
# 1.5320888862380118 1.3472963553339066
# 0.3472963553346955 -0.8793852415708359
# -1.8793852415718184 2.5320888862379523
